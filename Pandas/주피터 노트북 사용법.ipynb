# %% [markdown]
# # Jupyter Notebook
# ## code
#
# 주피터 노트북은 웹 브라우저 상에서 개발을 할 수 있는 도구이며, 코드를 Cell 단위로 묶어서 실행하고 그래프나 표, 그리고 이미지나 영상 등을 쉽게 볼 수 있어서 특히 데이터 관련 작업을 할 때 많이 활용됩니다.
#
# > 교육을 위한 강의 노트로도 아주 훌륭해요 !

# %% [markdown]
# ![%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%281%29.png](attachment:%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%281%29.png)

# %% [markdown]
# ![baekjoon.png](attachment:baekjoon.png)

# %% [markdown]
# ## 특징
#
# 1. 코드를 Cell 단위로 작성 및 실행
# 1. 마크다운을 통한 문서화
# 1. 그래프나 표 등을 실시간으로 확인
# 1. html, pdf 등 파일로 저장

# %% [markdown]
# ## 사전 학습 자료
#
# 다음 링크에서 파이썬 기본편에 대한 학습을 하실 수 있습니다.
# [나도 코딩 블로그](http://nadocoding.tistory.com)

# %%
# %%HTML
# <iframe width="640" height="320" src="https://www.youtube.com/embed/dJfq-eCi7KI" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="640" height="320" src="https://www.youtube.com/embed/dJfq-eCi7KI" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
print("a : 위쪽에 cell 삽입")
print("b : 아래쪽에 cell 삽입")
print("m : 마크다운 cell로 변경")
print("y : 코드 cell로 변경")
# Out:
# a : 위쪽에 cell 삽입
# b : 아래쪽에 cell 삽입
# m : 마크다운 cell로 변경
# y : 코드 cell로 변경

# %% [markdown]
# ## 파이썬 기본 문법

# %%
print('hello world')
# Out:
# hello world

# %%
print('환영합니다')
# Out:
# 환영합니다

# %%
name = "연탄이"
print(name)
# Out:
# 연탄이

# %%
print("ctrl + Enter : 현재 Cell 실행")
# Out:
# ctrl + Enter : 현재 Cell 실행

# %%
print("shift + Enter : 현재 Cell 실행 후 다음 Cell 선택")
# Out:
# shift + Enter : 현재 Cell 실행 후 다음 Cell 선택

# %%
print("Alt + Enter : 현재 Cell 실행 후 다음 위치에 Cell 삽입")
# Out:
# Alt + Enter : 현재 Cell 실행 후 다음 위치에 Cell 삽입

# %%
print("d, d : 명령모드 상태일 때 Cell 삭제")
# Out:
# d, d : 명령모드 상태일 때 Cell 삭제

# %%
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## 모듈 사용

# %%
import random
print(random.randint(1, 45))
# Out:
# 45

# %%
print("tab : 작성 가능한 코드 예시")
# Out:
# tab : 작성 가능한 코드 예시

# %%
# random.randint??

# %%
num = 3

# %%
num *= 2

# %%
num += 4

# %%
print(num)
# Out:
# 10

# %%
import time
for i in range(100):
    print(i)
    time.sleep(1)
# Out:
# 0
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24456/981321810.py in <module>
#       2 for i in range(100):
#       3     print(i)
# ----> 4     time.sleep(1)
#
# KeyboardInterrupt:

# %% [markdown]
# ---
#
# ## 시각화 예제 1 : 그래프
#
# - matplotlib를 이용하면 다양한 그래프를 그릴 수 있으며 수행 결과를 바로 확인 할 수 있습니다.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]);  # Plot some data on the axes.

# %% [markdown]
# ## 시각화 예제 2 : 테이블
#
# - pandas 는 복잡한 데이터를 분석할 때 아주 유용합니다.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

df = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, np.nan],[19, 439, 6, 452, 226,232]],
                  index=pd.Index(['Tumour (Positive)', 'Non-Tumour (Negative)'], name='Actual Label:'),
                  columns=pd.MultiIndex.from_product([['Decision Tree', 'Regression', 'Random'],['Tumour', 'Non-Tumour']], names=['Model:', 'Predicted:']))
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_52dd4_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th class="col_heading level0 col2" colspan="2">Regression</th>
#       <th class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th class="col_heading level1 col0" >Tumour</th>
#       <th class="col_heading level1 col1" >Non-Tumour</th>
#       <th class="col_heading level1 col2" >Tumour</th>
#       <th class="col_heading level1 col3" >Non-Tumour</th>
#       <th class="col_heading level1 col4" >Tumour</th>
#       <th class="col_heading level1 col5" >Non-Tumour</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Actual Label:</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...
