# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
plt.plot(x,y)
plt.show() # 그래프 위의 글자 숨기기

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic'  # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자 깨짐 현상 해결

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist] # 폰트 이름만 출력
# Out:
# ['DejaVu Sans Mono',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'DejaVu Serif Display',
#  'cmss10',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'cmb10',
#  'STIXSizeOneSym',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'STIXSizeFiveSym',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Display',
#  'cmex10',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'cmmi10',
#  'cmtt10',
#  'DejaVu Serif',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'cmr10',
#  'STIXGeneral',
#  'cmsy10',
#  'STIXSizeOneSym',
#  'STIXSizeFourSym',
#  'Lucida Sans',
#  'Bodoni MT',
#  'Proxy 4',
#  'HYPost-Medium',
#  'Microsoft New Tai Lue',
#  'Lucida Sans Typewriter',
#  'Curlz MT',
#  'Bauhaus 93',
#  'Rockwell Condensed',
#  'Javanese Text',
#  'Swis721 Ex BT',
#  'HoloLens MDL2 Assets',
#  'Proxy 1',
#  'High Tower Text',
#  'Bodoni MT',
#  'Constantia',
#  'Webdings',
#  'Garamond',
#  'Eras Bold ITC',
#  'SansSerif',
#  'Trebuchet MS',
#  'High Tower Text',
#  'Monospac821 BT',
#  'ISOCT3',
#  'Malgun Gothic',
#  'Maiandra GD',
#  'Gill Sans MT',
#  'Sitka',
#  'RomanT',
#  'Arial',
#  'Swis721 BT',
#  'Californian FB',
#  'Monotype Corsiva',
#  'Perpetua',
#  'BankGothic Md BT',
#  'TechnicLite',
#  'Segoe Print',
#  'Hancom MalangMalang',
#  'Bell MT',
#  'SansSerif',
#  'ZWAdobeF',
#  'ItalicT',
#  'Courier New',
#  'Segoe UI Emoji',
#  'Swis721 Cn BT',
#  'Lucida Calligraphy',
#  'Impact',
#  'Calibri',
#  'Comic Sans MS',
#  'Courier New',
#  'Lucida Sans Typewriter',
#  'Cambria',
#  'Times New Roman',
#  'Symbol',
#  'Chiller',
#  'Segoe UI',
#  'Showcard Gothic',
#  'Century Gothic',
#  'Bell MT',
#  'Gill Sans MT Condensed',
#  'Gill Sans Ultra Bold',
#  'Yu Gothic',
#  'Candara',
#  'Arial',
#  'Lucida Bright',
#  'Gill Sans Ultra Bold Condensed',
#  'Candara',
#  'Proxy 7',
#  'Microsoft Uighur',
#  'Edwardian Script ITC',
#  'Franklin Gothic Demi Cond',
#  'Old English Text MT',
#  'Bookman Old Style',
#  'ISOCP2',
#  'Microsoft Yi Baiti',
#  'Algerian',
#  'MS Gothic',
#  'Berlin Sans FB Demi',
#  'Leelawadee UI',
#  'OCR A Extended',
#  'Corbel',
#  'Centaur',
#  'Leelawadee',
#  'Calisto MT',
#  'Jokerman',
#  'CityBlueprint',
#  'Franklin Gothic Heavy',
#  'HYSinMyeongJo-Medium',
#  'Segoe UI',
#  'Microsoft PhagsPa',
#  'Times New Roman',
#  'HCR Dotum',
#  'LG Smart UI',
#  'Calibri',
#  'Lucida Bright',
#  'Franklin Gothic Book',
#  'Swis721 BdCnOul BT',
#  'GothicG',
#  'Monospac821 BT',
#  'ScriptS',
#  'Segoe UI',
#  'Playbill',
#  'Swis721 BdOul BT',
#  'Lucida Sans Typewriter',
#  'Perpetua',
#  'Swis721 Ex BT',
#  'Swis721 BlkEx BT',
#  'CommercialPi BT',
#  'Imprint MT Shadow',
#  'Proxy 3',
#  'Tw Cen MT Condensed Extra Bold',
#  'Microsoft JhengHei',
#  'Gadugi',
#  'Microsoft Himalaya',
#  'Snap ITC',
#  'Nirmala UI',
#  'Symusic',
#  'Ebrima',
#  'Proxy 5',
#  'SansSerif',
#  'Consolas',
#  'Simplex',
#  'Bodoni MT',
#  'HYPMokGak-Bold',
#  'UniversalMath1 BT',
#  'Haettenschweiler',
#  'HYGraphic-Medium',
#  'GreekC',
#  'Modern No. 20',
#  'Wide Latin',
#  'Microsoft New Tai Lue',
#  'CountryBlueprint',
#  'Dutch801 XBd BT',
#  'Berlin Sans FB',
#  'Goudy Old Style',
#  'GENISO',
#  'Pyunji R',
#  'Microsoft Tai Le',
#  'Century Schoolbook',
#  'Poor Richard',
#  'HYGothic-Extra',
#  'Dutch801 Rm BT',
#  'Segoe UI',
#  'Sitka',
#  'Gill Sans MT Ext Condensed Bold',
#  'Microsoft JhengHei',
#  'Pristina',
#  'Gulim',
#  'Txt',
#  'Lucida Fax',
#  'Dubai',
#  'Franklin Gothic Demi',
#  'Cambria',
#  'Swis721 LtEx BT',
#  'RomanD',
#  'SansSerif',
#  'Hancom MalangMalang',
#  'Adobe Devanagari',
#  'Verdana',
#  'AIGDT',
#  'Papyrus',
#  'LG PC',
#  'Felix Titling',
#  'HCR Batang',
#  'Swis721 Blk BT',
#  'New Gulim',
#  'Ravie',
#  'Swis721 Cn BT',
#  'LG Smart UI',
#  'Century Gothic',
#  'Niagara Solid',
#  'ISOCTEUR',
#  'Rockwell',
#  'Headline R',
#  'Monotxt',
#  'Candara',
#  'MS Reference Sans Serif',
#  'Agency FB',
#  'Baskerville Old Face',
#  'Swis721 LtCn BT',
#  'Corbel',
#  'BankGothic Lt BT',
#  'Verdana',
#  'Engravers MT',
#  'Stylus BT',
#  'Lucida Sans',
#  'Lucida Sans Unicode',
#  'Berlin Sans FB',
#  'Arial',
#  'Hancom Gothic',
#  'Palatino Linotype',
#  'HYGothic-Medium',
#  'Bodoni MT',
#  'Myanmar Text',
#  'Segoe UI',
#  'Microsoft Tai Le',
#  'Han Santteut Dotum',
#  'MV Boli',
#  'Corbel',
#  'Arial',
#  'Rage Italic',
#  'HCR Dotum',
#  'Lucida Bright',
#  'Microsoft YaHei',
#  'Swis721 BlkCn BT',
#  'Century Gothic',
#  'HCR Dotum Ext',
#  'Tw Cen MT',
#  'Proxy 6',
#  'Swis721 Lt BT',
#  'Nirmala UI',
#  'Bernard MT Condensed',
#  'Technic',
#  'Tw Cen MT',
#  'Wingdings',
#  'SimSun-ExtB',
#  'Segoe UI',
#  'Leelawadee UI',
#  'Consolas',
#  'Gill Sans MT',
#  'Romantic',
#  'Franklin Gothic Heavy',
#  'Tempus Sans ITC',
#  'Parchment',
#  'PanRoman',
#  'Bodoni MT',
#  'Calibri',
#  'Matura MT Script Capitals',
#  'Symeteo',
#  'ISOCP',
#  'AcadEref',
#  'Freestyle Script',
#  'Cooper Black',
#  'Candara',
#  'Californian FB',
#  'Segoe UI Variable',
#  'French Script MT',
#  'AmdtSymbols',
#  'ISOCPEUR',
#  'Segoe UI',
#  'Romantic',
#  'Blackadder ITC',
#  'Yu Gothic',
#  'Swis721 Cn BT',
#  'Segoe Script',
#  'Adobe Devanagari',
#  'Pyidaungsu',
#  'Han Santteut Dotum',
#  'Bodoni MT',
#  'Segoe MDL2 Assets',
#  'Yu Gothic',
#  'Tw Cen MT',
#  'Complex',
#  'Swis721 LtCn BT',
#  'MS Reference Specialty',
#  'Mongolian Baiti',
#  'Microsoft YaHei',
#  'Lucida Bright',
#  'Franklin Gothic Medium Cond',
#  'Consolas',
#  'Malgun Gothic',
#  'Magic R',
#  'Cambria',
#  'Tahoma',
#  'Segoe UI',
#  'Times New Roman',
#  'Garamond',
#  'Monospac821 BT',
#  'Arial',
#  'Georgia',
#  'LG Smart UI',
#  'Book Antiqua',
#  'Tahoma',
#  'Bahnschrift',
#  'Segoe Script',
#  'NewJumja',
#  'Magneto',
#  'Trebuchet MS',
#  'Calisto MT',
#  'Syastro',
#  'Marlett',
#  'Onyx',
#  'Comic Sans MS',
#  'Castellar',
#  'Copperplate Gothic Bold',
#  'EuroRoman',
#  'Harrington',
#  'HYHeadLine-Medium',
#  'Palatino Linotype',
#  'Broadway',
#  'Yet R',
#  'Century Gothic',
#  'HCR Batang ExtB',
#  'Corbel',
#  'ItalicC',
#  'HCR Batang Ext',
#  'Corbel',
#  'GDT',
#  'ISOCP3',
#  'HYPost-Light',
#  'Bodoni MT',
#  'Calisto MT',
#  'Dubai',
#  'Viner Hand ITC',
#  'Bell MT',
#  'Lucida Sans',
#  'Leelawadee',
#  'Dubai',
#  'ISOCT',
#  'Adobe Devanagari',
#  'Segoe UI Historic',
#  'Georgia',
#  'Comic Sans MS',
#  'Ink Free',
#  'Lucida Fax',
#  'AMGDT',
#  'Dutch801 Rm BT',
#  'Lucida Sans Typewriter',
#  'Monospac821 BT',
#  'HyhwpEQ',
#  'Vineta BT',
#  'SuperFrench',
#  'Rockwell Condensed',
#  'Swis721 BT',
#  'Informal Roman',
#  'Bookman Old Style',
#  'Proxy 9',
#  'Dubai',
#  'Proxy 8',
#  'Arial',
#  'Perpetua',
#  'Arial',
#  'HYShortSamul-Medium',
#  'GreekS',
#  'Bodoni MT',
#  'Rockwell',
#  'Trebuchet MS',
#  'Yu Gothic',
#  'Goudy Stout',
#  'Gloucester MT Extra Condensed',
#  'Calibri',
#  'Ami R',
#  'Goudy Old Style',
#  'Constantia',
#  'GothicI',
#  'Agency FB',
#  'Segoe Print',
#  'Hancom Gothic',
#  'Sylfaen',
#  'Calibri',
#  'Elephant',
#  'Dutch801 Rm BT',
#  'Vivaldi',
#  'Microsoft Uighur',
#  'Harlow Solid Italic',
#  'ISOCTEUR',
#  'Arial Rounded MT Bold',
#  'Gigi',
#  'Century',
#  'Malgun Gothic',
#  'Arial',
#  'Segoe UI Symbol',
#  'Perpetua Titling MT',
#  'Gill Sans MT',
#  'Georgia',
#  'MS Outlook',
#  'Gadugi',
#  'Gill Sans MT',
#  'Tw Cen MT Condensed',
#  'Goudy Old Style',
#  'Segoe UI',
#  'Britannic Bold',
#  'Candara',
#  'CommercialScript BT',
#  'Elephant',
#  'Georgia',
#  'Lucida Fax',
#  'Times New Roman',
#  'Bodoni MT',
#  'Arial',
#  'Dutch801 Rm BT',
#  'Swis721 Cn BT',
#  'Candara',
#  'Phetsarath OT',
#  'Footlight MT Light',
#  'Bookman Old Style',
#  'EuroRoman',
#  'Palatino Linotype',
#  'MingLiU-ExtB',
#  'Lucida Sans',
#  'Symap',
#  'Batang',
#  'Vladimir Script',
#  'Perpetua Titling MT',
#  'Romantic',
#  'Niagara Engraved',
#  'Century Schoolbook',
#  'Franklin Gothic Demi',
#  'Bodoni MT',
#  'Leelawadee UI',
#  'Book Antiqua',
#  'Constantia',
#  'LG Smart UI',
#  'Cambria',
#  'Kunstler Script',
#  'MT Extra',
#  'Wingdings 3',
#  'Lucida Fax',
#  'Lucida Console',
#  'Rockwell',
#  'Constantia',
#  'RomanS',
#  'Hancom Hoonminjeongeum_V',
#  'Swis721 BT',
#  'Eras Demi ITC',
#  'ScriptC',
#  'Perpetua',
#  'Nirmala UI',
#  'Swis721 Lt BT',
#  'Pyidaungsu Numbers',
#  'Brush Script MT',
#  'Book Antiqua',
#  'Symath',
#  'Microsoft JhengHei',
#  'Courier New',
#  'Copperplate Gothic Light',
#  'Juice ITC',
#  'Courier New',
#  'Segoe UI',
#  'Century Schoolbook',
#  'Kristen ITC',
#  'SimSun',
#  'Palace Script MT',
#  'Garamond',
#  'Microsoft PhagsPa',
#  'Book Antiqua',
#  'Swis721 BlkOul BT',
#  'Tw Cen MT Condensed',
#  'Forte',
#  'Swis721 BlkCn BT',
#  'Eras Medium ITC',
#  'Pyidaungsu',
#  'Microsoft Sans Serif',
#  'Segoe UI',
#  'Stencil',
#  'ISOCPEUR',
#  'Microsoft YaHei',
#  'RomanC',
#  'HCR Batang ExtB',
#  'Bookshelf Symbol 7',
#  'Mistral',
#  'ISOCT2',
#  'Corbel',
#  'Franklin Gothic Book',
#  'HYMyeongJo-Extra',
#  'Verdana',
#  'Segoe UI',
#  'Eras Light ITC',
#  'HancomEQN',
#  'Colonna MT',
#  'Franklin Gothic Medium',
#  'Bodoni MT',
#  'Calisto MT',
#  'Gabriola',
#  'TechnicBold',
#  'Haan Wing2',
#  'Trebuchet MS',
#  'Century Schoolbook',
#  'Rockwell Extra Bold',
#  'Bookman Old Style',
#  'Italic',
#  'Lucida Handwriting',
#  'Franklin Gothic Medium',
#  'Proxy 2',
#  'MoeumT R',
#  'Segoe Fluent Icons',
#  'Rockwell',
#  'Swis721 Blk BT',
#  'HYGungSo-Bold',
#  'Adobe Devanagari',
#  'Myanmar Text',
#  'HCR Batang',
#  'Consolas',
#  'Tw Cen MT',
#  'Calibri',
#  'Bradley Hand ITC',
#  'Wingdings 2',
#  'Script MT Bold',
#  'Comic Sans MS',
#  'Swis721 BT',
#  'Palatino Linotype',
#  'GothicE',
#  'Californian FB',
#  'Verdana',
#  'Ebrima']

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
# Out:
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\kenya\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
